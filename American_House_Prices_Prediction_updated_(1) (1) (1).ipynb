# %% [markdown]
# Here we have imported the libraries required for visualization and applying EDA Techniques.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# We have uploaded our dataset using pd.read_csv where we have copy pasted the path of our dataset location

# %%
df = pd.read_csv("/American_Housing_Data_20231209.csv")

# %% [markdown]
# Here we have used df.info() to display the total number of columns, non null values and datatypes for each column in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39981 entries, 0 to 39980
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Zip Code                 39981 non-null  int64
#  1   Price                    39981 non-null  float64
#  2   Beds                     39981 non-null  int64
#  3   Baths                    39981 non-null  int64
#  4   Living Space             39981 non-null  int64
#  5   Address                  39981 non-null  object
#  6   City                     39981 non-null  object
#  7   State                    39981 non-null  object
#  8   Zip Code Population      39981 non-null  int64
#  9   Zip Code Density         39981 non-null  float64
#  10  County                   39981 non-null  object
#  11  Median Household Income  39979 non-null  float64
#  12  Latitude                 39981 non-null  float64
#  13  Longitude                39981 non-null  float64
# ...

# %% [markdown]
# We used df.shape() to display the total number of rows and columns in the dataset

# %%
df.shape
# Out:
# (39981, 14)

# %% [markdown]
# The df.columns method is used to display each column name present in the dataset.

# %%
df.columns
# Out:
# Index(['Zip Code', 'Price', 'Beds', 'Baths', 'Living Space', 'Address', 'City',
#        'State', 'Zip Code Population', 'Zip Code Density', 'County',
#        'Median Household Income', 'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# We use df.nunique() to check the unique number of values in the dataset.

# %%
df.nunique()
# Out:
# Zip Code                    1733
# Price                       5196
# Beds                          31
# Baths                         28
# Living Space                4623
# Address                    38827
# City                         243
# State                         29
# Zip Code Population         1712
# Zip Code Density            1706
# County                        88
# Median Household Income     1722
# Latitude                    1733
# Longitude                   1733
# dtype: int64

# %% [markdown]
# df.isnull method is used to check whether there are any missing values present in the dataset or not.

# %%
df.isnull().sum()
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    2
# Latitude                   0
# Longitude                  0
# dtype: int64

# %% [markdown]
# df.describe which basically describes the whole dataset with values for both rows and columns

# %%
df.describe()
# Out:
#            Zip Code         Price          Beds         Baths  Living Space  \
# count  39981.000000  3.998100e+04  39981.000000  39981.000000  39981.000000
# mean   64833.391336  6.227771e+05      3.171682      2.466572   1901.522723
# std    25614.601116  9.469793e+05      1.308796      1.323042   1211.307257
# min    10013.000000  1.800000e+03      1.000000      1.000000      2.000000
# 25%    40215.000000  2.650000e+05      3.000000      2.000000   1200.000000
# 50%    74136.000000  3.999000e+05      3.000000      2.000000   1639.000000
# 75%    85730.000000  6.749900e+05      4.000000      3.000000   2265.000000
# max    98199.000000  3.800000e+07     54.000000     66.000000  74340.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         39981.000000      39981.000000             39979.000000
# mean          37726.201996       2379.412483            110837.259861
# std           18672.647445       2946.574792             47309.055715
# ...

# %% [markdown]
# This code is creating a scatter plot using the seaborn library (sns.scatterplot()). It visualizes the relationship between two variables, 'Beds' and 'Price', from the DataFrame df.
#
# The x-axis represents the number of beds ('Beds'), while the y-axis represents the price ('Price'). Each point on the plot corresponds to a data entry in the DataFrame, with the x-coordinate indicating the number of beds and the y-coordinate indicating the price.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Beds', y='Price', data=df, color='blue', alpha=0.6)
plt.title('Relationship between Beds and Price')
plt.xlabel('Beds')
plt.ylabel('Price(in $)')
plt.show()

# %% [markdown]
# This code is creating a scatter plot using the seaborn library (sns.scatterplot()). It visualizes the relationship between two variables, 'Baths' and 'Price', from the DataFrame df.
#
# The x-axis represents the number of baths ('Baths'), while the y-axis represents the price ('Price'). Each point on the plot corresponds to a data entry in the DataFrame, with the x-coordinate indicating the number of baths and the y-coordinate indicating the price.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Baths', y='Price', data=df, color='green', alpha=0.6)
plt.title('Relationship between Baths and Price')
plt.xlabel('Baths')
plt.ylabel('Price (in $)')
plt.show()

# %% [markdown]
# This code is creating a scatter plot using the seaborn library (sns.scatterplot()). It visualizes the relationship between two variables, 'Living Space' and 'Price', from the DataFrame df.
#
# The x-axis represents the number of living space ('Living Space'), while the y-axis represents the price ('Price'). Each point on the plot corresponds to a data entry in the DataFrame, with the x-coordinate indicating the number of Living Space and the y-coordinate indicating the price.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Living Space', y='Price', data=df, color='orange', alpha=0.6)
plt.title('Relationship between Living Space and Price')
plt.xlabel('Living Space (sqft)')
plt.ylabel('Price(in $)')
plt.show()

# %% [markdown]
# df.sort_values(by='Price', ascending=False): This line sorts the DataFrame df by the column named 'Price' in descending order (ascending=False), meaning the cities with the highest prices will be at the top.
#
# expensive_cities = df.sort_values(by='Price', ascending=False): The sorted DataFrame is stored in a new variable called expensive_cities.
#
# top_10_expensive_cities = expensive_cities.head(10): This line selects the first 10 rows (cities) from the expensive_cities DataFrame, which effectively gives you the top 10 most expensive cities.
#
# top_10_expensive_cities[['City', 'Price']]: Finally, this line selects only the 'City' and 'Price' columns from the top_10_expensive_cities DataFrame, providing a summary of the top 10 most expensive cities and their corresponding prices.

# %%
expensive_cities = df.sort_values(by='Price', ascending=False)

top_10_expensive_cities = expensive_cities.head(10)

top_10_expensive_cities[['City', 'Price']]
# Out:
#                     City       Price
# 32369        Los Angeles  38000000.0
# 35645      San Francisco  32000000.0
# 1629          Washington  31900000.0
# 7665               Miami  31500000.0
# 32634     West Hollywood  28500000.0
# 35741      San Francisco  25000000.0
# 32638        Los Angeles  23888000.0
# 33616           La Jolla  23800000.0
# 32672  Pacific Palisades  22495000.0
# 7663               Miami  22000000.0

# %% [markdown]
# cheap_cities = df.sort_values(by='Price', ascending=False): This line sorts the DataFrame df by the column 'Price' in descending order (highest to lowest) and assigns the result to the variable cheap_cities.
#
# top_10_cheap_cities = expensive_cities.tail(10): This line creates a new DataFrame top_10_cheap_cities by selecting the last 10 rows (cities) from the DataFrame expensive_cities. However, there's a discrepancy here. It should be cheap_cities.tail(10) instead of expensive_cities.tail(10), given that cheap_cities was sorted by price in descending order.
#
# top_10_cheap_cities[['City', 'Price']]: This line selects only the 'City' and 'Price' columns from the DataFrame top_10_cheap_cities.

# %%
cheap_cities = df.sort_values(by='Price', ascending=False)

top_10_cheap_cities = expensive_cities.tail(10)

top_10_cheap_cities[['City', 'Price']]
# Out:
#                 City   Price
# 304         Brooklyn  3000.0
# 322         Brooklyn  2750.0
# 69     Staten Island  2500.0
# 306         Brooklyn  2500.0
# 330         Brooklyn  2500.0
# 112    Staten Island  2200.0
# 18133    New Orleans  2000.0
# 34393         Fresno  1995.0
# 7928           Miami  1950.0
# 94     Staten Island  1800.0

# %% [markdown]
# top_10_states = df['State'].value_counts().nlargest(10).index:
#
# df['State'].value_counts(): This counts the occurrences of each unique value in the 'State' column of the DataFrame df.
# .nlargest(10): This selects the 10 largest counts.
# .index: This extracts the index labels (which are the state names in this case) of the resulting Series.
# So, top_10_states contains the names of the top 10 states with the most properties in the DataFrame.
# df_top_10_states = df[df['State'].isin(top_10_states)]:
#
# df['State'].isin(top_10_states): This creates a boolean mask indicating whether each row's 'State' value is in the top_10_states.
# df[df['State'].isin(top_10_states)]: This filters the DataFrame df to include only the rows where the 'State' value is in the top_10_states.
# So, df_top_10_states contains only the rows from the original DataFrame df that correspond to the top 10 states with the most properties.
# plt.figure(figsize=(12, 6)):
#
# This initializes a new figure for plotting with a specified size of 12 inches in width and 6 inches in height.
# sns.countplot(x='State', data=df_top_10_states, palette='muted', order=top_10_states):
#
# sns.countplot: This is a seaborn function used to plot the count of observations in each category.
# x='State': This specifies that the 'State' column will be plotted on the x-axis.
# data=df_top_10_states: This specifies the DataFrame from which the data will be taken.
# palette='muted': This sets the color palette for the plot.
# order=top_10_states: This specifies the order in which the states will be plotted on the x-axis, based on top_10_states.
# This line generates the count plot showing the distribution of properties across the top 10 states.
# plt.title('Top 10 States with the Most Properties'):
#
# This sets the title of the plot.
# plt.xlabel('State') and plt.ylabel('Count'):
#
# These set the labels for the x-axis and y-axis respectively.
# plt.show():
#
# This displays the plot.

# %%
top_10_states = df['State'].value_counts().nlargest(10).index

df_top_10_states = df[df['State'].isin(top_10_states)]

plt.figure(figsize=(12, 6))
sns.countplot(x='State', data=df_top_10_states, palette='muted', order=top_10_states)
plt.title('Top 10 States with the Most Properties')
plt.xlabel('State')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# top_10_country = df['County'].value_counts().nlargest(10).index:
#
# df['County'].value_counts(): This counts the occurrences of each unique value in the 'County' column of the DataFrame df.
# .nlargest(10): This selects the 10 largest counts.
# .index: This extracts the index labels (which are the county names in this case) of the resulting Series.
# So, top_10_country contains the names of the top 10 counties with the most properties in the DataFrame.
# df_top_10_country = df[df['County'].isin(top_10_country)]:
#
# df['County'].isin(top_10_country): This creates a boolean mask indicating whether each row's 'County' value is in the top_10_country.
# df[df['County'].isin(top_10_country)]: This filters the DataFrame df to include only the rows where the 'County' value is in the top_10_country.
# So, df_top_10_country contains only the rows from the original DataFrame df that correspond to the top 10 counties with the most properties.
# plt.figure(figsize=(12, 6)):
#
# This initializes a new figure for plotting with a specified size of 12 inches in width and 6 inches in height.
# sns.countplot(x='County', data=df_top_10_country, palette='muted', order=top_10_country):
#
# sns.countplot: This is a seaborn function used to plot the count of observations in each category.
# x='County': This specifies that the 'County' column will be plotted on the x-axis.
# data=df_top_10_country: This specifies the DataFrame from which the data will be taken.
# palette='muted': This sets the color palette for the plot.
# order=top_10_country: This specifies the order in which the counties will be plotted on the x-axis, based on top_10_country.
# This line generates the count plot showing the distribution of properties across the top 10 counties.
# plt.title('Top 10 County with the Most Properties'):
#
# This sets the title of the plot.
# plt.xlabel('County') and plt.ylabel('Count'):
#
# These set the labels for the x-axis and y-axis respectively.
# plt.show():
#
# This displays the plot.

# %%
top_10_country = df['County'].value_counts().nlargest(10).index

df_top_10_country = df[df['County'].isin(top_10_country)]

plt.figure(figsize=(12, 6))
sns.countplot(x='County', data=df_top_10_country, palette='muted', order=top_10_country)
plt.title('Top 10 Country with the Most Properties')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Bar Plot for cities with best median Income to Price Per Sqr foot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

housing_data = pd.read_csv('/content/American_Housing_Data_20231209.csv')
# Calculate price per living space (in dollars per square foot) and group data by city
housing_data['Price Per Living Space'] = housing_data['Price'] / housing_data['Living Space']
city_grouped_data = housing_data.groupby('City').agg({
    'Median Household Income': 'median',
    'Price Per Living Space': 'mean'
}).reset_index()

# Calculate the ratio of median household income to price per living space for each city
city_grouped_data['Income to Price Ratio'] = city_grouped_data['Median Household Income'] / city_grouped_data['Price Per Living Space']

# Sort the cities by their income to price ratio and select the top 8
top_cities = city_grouped_data.sort_values(by='Income to Price Ratio', ascending=False).head(8)

# Create a factorplot for these top 5 cities
plt.figure(figsize=(10, 6))
sns.catplot(x='City', y='Income to Price Ratio', kind='bar', data=top_cities, height=6, aspect=2)
plt.title('Top 5 Cities with Best Median Income to Price Per Living Space Ratios')
plt.ylabel('Income to Price Ratio')
plt.xlabel('City')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Comparing 2 cities

# %%
# Filter the dataset for New York and Chicago
cities_filter = housing_data['City'].isin(['New York', 'Chicago'])
cities_data = housing_data[cities_filter]

# Regression plot for Price vs. Living Space in New York and Chicago
plt.figure(figsize=(12, 6))
sns.lmplot(x='Living Space', y='Price', hue='City', data=cities_data, aspect=2, height=6)
plt.title('Regression Plot: Price vs. Living Space for New York and Chicago')
plt.xlabel('Living Space (sqft)')
plt.ylabel('Price ($)')
plt.show()

# %%
# Calculating additional metrics for comparison
cities_data['Bed to Bath Ratio'] = cities_data['Beds'] / cities_data['Baths']
cities_comparison_metrics = cities_data.groupby('City').agg({
    'Price Per Living Space': 'mean',
    'Median Household Income': 'median',
    'Address': 'count',  # Number of apartments available
    'Living Space': 'mean',
    'Bed to Bath Ratio': 'mean'
}).reset_index().melt(id_vars='City')

# Plotting the comparisons in a grid
g = sns.FacetGrid(cities_comparison_metrics, col='variable', sharey=False, sharex=False, col_wrap=2, height=4, aspect=1.5)
g.map_dataframe(sns.barplot, x='City', y='value', hue='City', palette='coolwarm')
g.add_legend()
g.set_titles(col_template="{col_name}")
g.set_axis_labels("", "Value")
g.fig.suptitle('Comparison of Metrics Between New York and Chicago', y=1.02)

# Adjusting layout for better readability
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-9-75305cc409dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities_data['Bed to Bath Ratio'] = cities_data['Beds'] / cities_data['Baths']

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import numpy as np

# Load your street map and housing data
street_map = gpd.read_file('/content/geo_export_ff55341a-2adb-403a-9ae3-a80da8a85141.shp')
df = pd.read_csv('/content/American_Housing_Data_20231209.csv')

# Filter data for specific cities and state
cities = ["New York", "Brooklyn", "Queens Village", "Bronx", "Staten Island"]
state = ["New York"]
filtered_df = df[df['City'].isin(cities) & df['State'].isin(state)]

# Create GeoDataFrame
crs = {"init": "epsg:4326"}
geometry = [Point(xy) for xy in zip(filtered_df["Longitude"], filtered_df["Latitude"])]
geo_df = gpd.GeoDataFrame(filtered_df, crs=crs, geometry=geometry)

# Plotting
fig, ax = plt.subplots(figsize=(15, 15))
street_map.plot(ax=ax, color="grey", alpha=0.3)  # Base map

# Using 'Price' directly for color
scatter = ax.scatter(geo_df['geometry'].x, geo_df['geometry'].y, c=geo_df['Price'], s=50, cmap='inferno', alpha=1)

# Adding colorbar
fig.colorbar(scatter, ax=ax, label='Price')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Housing Prices in New York City')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
